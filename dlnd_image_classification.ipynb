# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/input/cifar-10/python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np
import sklearn


# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    return np.array((x - np.min(x)) / (np.max(x) - np.min(x)))


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
#
# Hint: Don't reinvent the wheel.

# %%
lb_encoding = None
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    global lb_encoding

    if lb_encoding is not None:
        return lb_encoding.transform(x)
    else:
        labels = np.array(x)
        lb_encoding = sklearn.preprocessing.LabelBinarizer()
        lb_encoding.fit(labels)
        return lb_encoding.transform(labels)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf


def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    return tf.placeholder(tf.float32, shape=[None, image_shape[0], image_shape[1], image_shape[2]], name='x')


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    return tf.placeholder(tf.float32, shape=[None, n_classes], name='y')


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    return tf.placeholder(tf.float32, None, name='keep_prob')


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor

    """
    weights = tf.Variable(tf.truncated_normal([conv_ksize[0],conv_ksize[1], x_tensor.get_shape().as_list()[3], conv_num_outputs]))
    bias = tf.Variable(tf.zeros(conv_num_outputs))
    
    convolution = tf.nn.conv2d(x_tensor, weights, strides=[1,conv_strides[0],conv_strides[1],1], padding='SAME')
    convolution_and_bias = tf.nn.bias_add(convolution, bias)
    
    convolution_and_bias_activation = tf.nn.relu(convolution_and_bias)
    
    max_pool = tf.nn.max_pool(convolution_and_bias_activation, [1,pool_ksize[0],pool_ksize[1],1], strides=[1,pool_strides[0],pool_strides[1],1], padding='SAME')
    return max_pool


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    return tf.contrib.layers.flatten(x_tensor)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    #dimension = x_tensor.get_shape().as_list()
    #shape = list( (dimension[-1],) + (num_outputs,))
    #weight = tf.Variable(tf.truncated_normal(shape,0,0.1))
    #bias = tf.Variable(tf.zeros(num_outputs))
    #return tf.nn.relu(tf.add(tf.matmul(x_tensor,weight), bias))
    return tf.contrib.layers.fully_connected(x_tensor, num_outputs, activation_fn=tf.nn.relu)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    dimension = x_tensor.get_shape().as_list()
    shape = list( (dimension[-1],) + (num_outputs,))
    weight = tf.Variable(tf.truncated_normal(shape,0,0.01))
    bias = tf.Variable(tf.zeros(num_outputs))
    return tf.add(tf.matmul(x_tensor,weight), bias)
    #return tf.contrib.layers.fully_connected(x_tensor, num_outputs)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    conv1 = conv2d_maxpool(x, conv_num_outputs=18, conv_ksize=(4,4), conv_strides=(1,1), pool_ksize=(8,8), pool_strides=(1,1))
    conv1 = tf.nn.dropout(conv1, keep_prob)

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    flatten_layer = flatten(conv1)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    fully_connected_layer = fully_conn(flatten_layer, 384)
    fully_connected_layer = tf.nn.dropout(fully_connected_layer, keep_prob)

    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    output_layer = output(fully_connected_layer, 10)
    
    # TODO: return output
    return output_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict={x:feature_batch, y:label_batch, keep_prob:keep_probability})
    

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    loss = session.run(cost, feed_dict={x: feature_batch, y:label_batch, keep_prob:1.})
    valid_accuracy = session.run(accuracy, feed_dict={x: valid_features, y: valid_labels, keep_prob: 1.})
    
    print('Loss: {:>10.4f}'.format(loss))
    print('Accuracy: {:.6f}'.format(valid_accuracy))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 100
batch_size = 512
keep_probability = 0.3

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     2.2874
# Accuracy: 0.105600
# Epoch  2, CIFAR-10 Batch 1:  Loss:     2.2601
# Accuracy: 0.145800
# Epoch  3, CIFAR-10 Batch 1:  Loss:     2.1732
# Accuracy: 0.230200
# Epoch  4, CIFAR-10 Batch 1:  Loss:     2.1584
# Accuracy: 0.257600
# Epoch  5, CIFAR-10 Batch 1:  Loss:     2.0829
# Accuracy: 0.255800
# Epoch  6, CIFAR-10 Batch 1:  Loss:     2.0685
# Accuracy: 0.260200
# Epoch  7, CIFAR-10 Batch 1:  Loss:     2.0429
# Accuracy: 0.276200
# Epoch  8, CIFAR-10 Batch 1:  Loss:     2.0621
# Accuracy: 0.256000
# Epoch  9, CIFAR-10 Batch 1:  Loss:     2.0078
# Accuracy: 0.272800
# Epoch 10, CIFAR-10 Batch 1:  Loss:     2.0041
# Accuracy: 0.292000
# Epoch 11, CIFAR-10 Batch 1:  Loss:     1.9767
# Accuracy: 0.296800
# Epoch 12, CIFAR-10 Batch 1:  Loss:     2.0036
# Accuracy: 0.312600
# Epoch 13, CIFAR-10 Batch 1:  Loss:     1.9646
# Accuracy: 0.285600
# Epoch 14, CIFAR-10 Batch 1:  Loss:     1.9588
# Accuracy: 0.329800
# Epoch 15, CIFAR-10 Batch 1:  Loss:     1.9652
# Accuracy: 0.314600
# Epoch 16, CIFAR-10 Batch 1:  Loss:     1.9380
# Accuracy: 0.327000
# Epoch 17, CIFAR-10 Batch 1:  Loss:     1.9203
# Accuracy: 0.323800
# Epoch 18, CIFAR-10 Batch 1:  Loss:     1.9507
# Accuracy: 0.331200
# Epoch 19, CIFAR-10 Batch 1:  Loss:     1.9093
# Accuracy: 0.357000
# Epoch 20, CIFAR-10 Batch 1:  Loss:     1.9212
# Accuracy: 0.309800
# Epoch 21, CIFAR-10 Batch 1:  Loss:     1.8942
# Accuracy: 0.321400
# Epoch 22, CIFAR-10 Batch 1:  Loss:     1.8928
# Accuracy: 0.341800
# Epoch 23, CIFAR-10 Batch 1:  Loss:     1.8996
# Accuracy: 0.319000
# Epoch 24, CIFAR-10 Batch 1:  Loss:     1.8833
# Accuracy: 0.328800
# Epoch 25, CIFAR-10 Batch 1:  Loss:     1.8913
# Accuracy: 0.328000
# Epoch 26, CIFAR-10 Batch 1:  Loss:     1.8778
# Accuracy: 0.336400
# Epoch 27, CIFAR-10 Batch 1:  Loss:     1.9049
# Accuracy: 0.354400
# Epoch 28, CIFAR-10 Batch 1:  Loss:     1.8682
# Accuracy: 0.355600
# Epoch 29, CIFAR-10 Batch 1:  Loss:     1.8617
# Accuracy: 0.344800
# Epoch 30, CIFAR-10 Batch 1:  Loss:     1.8712
# Accuracy: 0.360000
# Epoch 31, CIFAR-10 Batch 1:  Loss:     1.8538
# Accuracy: 0.350800
# Epoch 32, CIFAR-10 Batch 1:  Loss:     1.8471
# Accuracy: 0.338000
# Epoch 33, CIFAR-10 Batch 1:  Loss:     1.8716
# Accuracy: 0.329600
# Epoch 34, CIFAR-10 Batch 1:  Loss:     1.8548
# Accuracy: 0.343600
# Epoch 35, CIFAR-10 Batch 1:  Loss:     1.8398
# Accuracy: 0.348200
# Epoch 36, CIFAR-10 Batch 1:  Loss:     1.8594
# Accuracy: 0.362400
# Epoch 37, CIFAR-10 Batch 1:  Loss:     1.8326
# Accuracy: 0.371000
# Epoch 38, CIFAR-10 Batch 1:  Loss:     1.8245
# Accuracy: 0.373600
# Epoch 39, CIFAR-10 Batch 1:  Loss:     1.8458
# Accuracy: 0.375400
# Epoch 40, CIFAR-10 Batch 1:  Loss:     1.8489
# Accuracy: 0.350400
# Epoch 41, CIFAR-10 Batch 1:  Loss:     1.8358
# Accuracy: 0.337200
# Epoch 42, CIFAR-10 Batch 1:  Loss:     1.8145
# Accuracy: 0.357000
# Epoch 43, CIFAR-10 Batch 1:  Loss:     1.7924
# Accuracy: 0.391200
# Epoch 44, CIFAR-10 Batch 1:  Loss:     1.7853
# Accuracy: 0.404200
# Epoch 45, CIFAR-10 Batch 1:  Loss:     1.8117
# Accuracy: 0.384400
# Epoch 46, CIFAR-10 Batch 1:  Loss:     1.7939
# Accuracy: 0.340000
# Epoch 47, CIFAR-10 Batch 1:  Loss:     1.7974
# Accuracy: 0.372400
# Epoch 48, CIFAR-10 Batch 1:  Loss:     1.7794
# Accuracy: 0.381200
# Epoch 49, CIFAR-10 Batch 1:  Loss:     1.7577
# Accuracy: 0.400600
# Epoch 50, CIFAR-10 Batch 1:  Loss:     1.7600
# Accuracy: 0.376000
# Epoch 51, CIFAR-10 Batch 1:  Loss:     1.7549
# Accuracy: 0.393800
# Epoch 52, CIFAR-10 Batch 1:  Loss:     1.7633
# Accuracy: 0.371200
# Epoch 53, CIFAR-10 Batch 1:  Loss:     1.7338
# Accuracy: 0.388800
# Epoch 54, CIFAR-10 Batch 1:  Loss:     1.7460
# Accuracy: 0.385800
# Epoch 55, CIFAR-10 Batch 1:  Loss:     1.7285
# Accuracy: 0.398600
# Epoch 56, CIFAR-10 Batch 1:  Loss:     1.7231
# Accuracy: 0.392600
# Epoch 57, CIFAR-10 Batch 1:  Loss:     1.7176
# Accuracy: 0.384000
# Epoch 58, CIFAR-10 Batch 1:  Loss:     1.7199
# Accuracy: 0.380600
# Epoch 59, CIFAR-10 Batch 1:  Loss:     1.7066
# Accuracy: 0.392200
# Epoch 60, CIFAR-10 Batch 1:  Loss:     1.7197
# Accuracy: 0.385200
# Epoch 61, CIFAR-10 Batch 1:  Loss:     1.7113
# Accuracy: 0.397800
# Epoch 62, CIFAR-10 Batch 1:  Loss:     1.7284
# Accuracy: 0.388800
# Epoch 63, CIFAR-10 Batch 1:  Loss:     1.7246
# Accuracy: 0.403400
# Epoch 64, CIFAR-10 Batch 1:  Loss:     1.7202
# Accuracy: 0.400800
# Epoch 65, CIFAR-10 Batch 1:  Loss:     1.6980
# Accuracy: 0.395200
# Epoch 66, CIFAR-10 Batch 1:  Loss:     1.7099
# Accuracy: 0.402400
# Epoch 67, CIFAR-10 Batch 1:  Loss:     1.7046
# Accuracy: 0.408000
# Epoch 68, CIFAR-10 Batch 1:  Loss:     1.7224
# Accuracy: 0.385000
# Epoch 69, CIFAR-10 Batch 1:  Loss:     1.6944
# Accuracy: 0.399600
# Epoch 70, CIFAR-10 Batch 1:  Loss:     1.7107
# Accuracy: 0.396800
# Epoch 71, CIFAR-10 Batch 1:  Loss:     1.6662
# Accuracy: 0.394200
# Epoch 72, CIFAR-10 Batch 1:  Loss:     1.6799
# Accuracy: 0.373600
# Epoch 73, CIFAR-10 Batch 1:  Loss:     1.6656
# Accuracy: 0.404200
# Epoch 74, CIFAR-10 Batch 1:  Loss:     1.6510
# Accuracy: 0.426000
# Epoch 75, CIFAR-10 Batch 1:  Loss:     1.6516
# Accuracy: 0.412000
# Epoch 76, CIFAR-10 Batch 1:  Loss:     1.6599
# Accuracy: 0.405800
# Epoch 77, CIFAR-10 Batch 1:  Loss:     1.6802
# Accuracy: 0.394400
# Epoch 78, CIFAR-10 Batch 1:  Loss:     1.6602
# Accuracy: 0.402000
# Epoch 79, CIFAR-10 Batch 1:  Loss:     1.6617
# Accuracy: 0.409200
# Epoch 80, CIFAR-10 Batch 1:  Loss:     1.6402
# Accuracy: 0.414200
# Epoch 81, CIFAR-10 Batch 1:  Loss:     1.6556
# Accuracy: 0.400000
# Epoch 82, CIFAR-10 Batch 1:  Loss:     1.6564
# Accuracy: 0.410200
# Epoch 83, CIFAR-10 Batch 1:  Loss:     1.6694
# Accuracy: 0.378800
# Epoch 84, CIFAR-10 Batch 1:  Loss:     1.6601
# Accuracy: 0.395600
# Epoch 85, CIFAR-10 Batch 1:  Loss:     1.6934
# Accuracy: 0.402000
# Epoch 86, CIFAR-10 Batch 1:  Loss:     1.6517
# Accuracy: 0.391800
# Epoch 87, CIFAR-10 Batch 1:  Loss:     1.6380
# Accuracy: 0.411600
# Epoch 88, CIFAR-10 Batch 1:  Loss:     1.6556
# Accuracy: 0.407800
# Epoch 89, CIFAR-10 Batch 1:  Loss:     1.6292
# Accuracy: 0.406000
# Epoch 90, CIFAR-10 Batch 1:  Loss:     1.6381
# Accuracy: 0.409000
# Epoch 91, CIFAR-10 Batch 1:  Loss:     1.6433
# Accuracy: 0.412800
# Epoch 92, CIFAR-10 Batch 1:  Loss:     1.6585
# Accuracy: 0.417000
# Epoch 93, CIFAR-10 Batch 1:  Loss:     1.6239
# Accuracy: 0.420600
# Epoch 94, CIFAR-10 Batch 1:  Loss:     1.6342
# Accuracy: 0.424800
# Epoch 95, CIFAR-10 Batch 1:  Loss:     1.6341
# Accuracy: 0.412600
# Epoch 96, CIFAR-10 Batch 1:  Loss:     1.6565
# Accuracy: 0.410400
# Epoch 97, CIFAR-10 Batch 1:  Loss:     1.6323
# Accuracy: 0.409600
# Epoch 98, CIFAR-10 Batch 1:  Loss:     1.6384
# Accuracy: 0.408000
# Epoch 99, CIFAR-10 Batch 1:  Loss:     1.6224
# Accuracy: 0.397200
# Epoch 100, CIFAR-10 Batch 1:  Loss:     1.6298
# Accuracy: 0.418200

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     2.1329
# Accuracy: 0.238400
# Epoch  1, CIFAR-10 Batch 2:  Loss:     1.9494
# Accuracy: 0.276800
# Epoch  1, CIFAR-10 Batch 3:  Loss:     1.9260
# Accuracy: 0.299800
# Epoch  1, CIFAR-10 Batch 4:  Loss:     1.8451
# Accuracy: 0.257600
# Epoch  1, CIFAR-10 Batch 5:  Loss:     1.8862
# Accuracy: 0.275400
# Epoch  2, CIFAR-10 Batch 1:  Loss:     1.9355
# Accuracy: 0.270800
# Epoch  2, CIFAR-10 Batch 2:  Loss:     1.8740
# Accuracy: 0.265600
# Epoch  2, CIFAR-10 Batch 3:  Loss:     1.7856
# Accuracy: 0.307000
# Epoch  2, CIFAR-10 Batch 4:  Loss:     1.7741
# Accuracy: 0.272600
# Epoch  2, CIFAR-10 Batch 5:  Loss:     1.8051
# Accuracy: 0.295200
# Epoch  3, CIFAR-10 Batch 1:  Loss:     1.8530
# Accuracy: 0.310200
# Epoch  3, CIFAR-10 Batch 2:  Loss:     1.7862
# Accuracy: 0.324400
# Epoch  3, CIFAR-10 Batch 3:  Loss:     1.7677
# Accuracy: 0.306800
# Epoch  3, CIFAR-10 Batch 4:  Loss:     1.6948
# Accuracy: 0.349600
# Epoch  3, CIFAR-10 Batch 5:  Loss:     1.7951
# Accuracy: 0.334400
# Epoch  4, CIFAR-10 Batch 1:  Loss:     1.8416
# Accuracy: 0.347000
# Epoch  4, CIFAR-10 Batch 2:  Loss:     1.7783
# Accuracy: 0.325600
# Epoch  4, CIFAR-10 Batch 3:  Loss:     1.7262
# Accuracy: 0.335200
# Epoch  4, CIFAR-10 Batch 4:  Loss:     1.6682
# Accuracy: 0.355800
# Epoch  4, CIFAR-10 Batch 5:  Loss:     1.7521
# Accuracy: 0.328200
# Epoch  5, CIFAR-10 Batch 1:  Loss:     1.8014
# Accuracy: 0.358800
# Epoch  5, CIFAR-10 Batch 2:  Loss:     1.7670
# Accuracy: 0.359000
# Epoch  5, CIFAR-10 Batch 3:  Loss:     1.7281
# Accuracy: 0.329600
# Epoch  5, CIFAR-10 Batch 4:  Loss:     1.6611
# Accuracy: 0.371000
# Epoch  5, CIFAR-10 Batch 5:  Loss:     1.7248
# Accuracy: 0.335800
# Epoch  6, CIFAR-10 Batch 1:  Loss:     1.7849
# Accuracy: 0.368800
# Epoch  6, CIFAR-10 Batch 2:  Loss:     1.7411
# Accuracy: 0.370400
# Epoch  6, CIFAR-10 Batch 3:  Loss:     1.6825
# Accuracy: 0.353200
# Epoch  6, CIFAR-10 Batch 4:  Loss:     1.6187
# Accuracy: 0.380200
# Epoch  6, CIFAR-10 Batch 5:  Loss:     1.6953
# Accuracy: 0.348800
# Epoch  7, CIFAR-10 Batch 1:  Loss:     1.7770
# Accuracy: 0.385600
# Epoch  7, CIFAR-10 Batch 2:  Loss:     1.7155
# Accuracy: 0.359600
# Epoch  7, CIFAR-10 Batch 3:  Loss:     1.6494
# Accuracy: 0.371800
# Epoch  7, CIFAR-10 Batch 4:  Loss:     1.6199
# Accuracy: 0.376400
# Epoch  7, CIFAR-10 Batch 5:  Loss:     1.6998
# Accuracy: 0.361600
# Epoch  8, CIFAR-10 Batch 1:  Loss:     1.7498
# Accuracy: 0.394200
# Epoch  8, CIFAR-10 Batch 2:  Loss:     1.6967
# Accuracy: 0.394200
# Epoch  8, CIFAR-10 Batch 3:  Loss:     1.6220
# Accuracy: 0.385400
# Epoch  8, CIFAR-10 Batch 4:  Loss:     1.5842
# Accuracy: 0.402000
# Epoch  8, CIFAR-10 Batch 5:  Loss:     1.6419
# Accuracy: 0.381000
# Epoch  9, CIFAR-10 Batch 1:  Loss:     1.7143
# Accuracy: 0.398600
# Epoch  9, CIFAR-10 Batch 2:  Loss:     1.6611
# Accuracy: 0.388600
# Epoch  9, CIFAR-10 Batch 3:  Loss:     1.6315
# Accuracy: 0.346200
# Epoch  9, CIFAR-10 Batch 4:  Loss:     1.5981
# Accuracy: 0.392400
# Epoch  9, CIFAR-10 Batch 5:  Loss:     1.6777
# Accuracy: 0.357400
# Epoch 10, CIFAR-10 Batch 1:  Loss:     1.7176
# Accuracy: 0.401200
# Epoch 10, CIFAR-10 Batch 2:  Loss:     1.6631
# Accuracy: 0.407400
# Epoch 10, CIFAR-10 Batch 3:  Loss:     1.5725
# Accuracy: 0.425200
# Epoch 10, CIFAR-10 Batch 4:  Loss:     1.5630
# Accuracy: 0.403800
# Epoch 10, CIFAR-10 Batch 5:  Loss:     1.6363
# Accuracy: 0.392400
# Epoch 11, CIFAR-10 Batch 1:  Loss:     1.7222
# Accuracy: 0.386400
# Epoch 11, CIFAR-10 Batch 2:  Loss:     1.6578
# Accuracy: 0.422600
# Epoch 11, CIFAR-10 Batch 3:  Loss:     1.5565
# Accuracy: 0.407800
# Epoch 11, CIFAR-10 Batch 4:  Loss:     1.5428
# Accuracy: 0.399200
# Epoch 11, CIFAR-10 Batch 5:  Loss:     1.6270
# Accuracy: 0.410800
# Epoch 12, CIFAR-10 Batch 1:  Loss:     1.6850
# Accuracy: 0.425600
# Epoch 12, CIFAR-10 Batch 2:  Loss:     1.6313
# Accuracy: 0.432600
# Epoch 12, CIFAR-10 Batch 3:  Loss:     1.5457
# Accuracy: 0.419200
# Epoch 12, CIFAR-10 Batch 4:  Loss:     1.5415
# Accuracy: 0.433000
# Epoch 12, CIFAR-10 Batch 5:  Loss:     1.6331
# Accuracy: 0.413200
# Epoch 13, CIFAR-10 Batch 1:  Loss:     1.6743
# Accuracy: 0.434600
# Epoch 13, CIFAR-10 Batch 2:  Loss:     1.6240
# Accuracy: 0.422400
# Epoch 13, CIFAR-10 Batch 3:  Loss:     1.5257
# Accuracy: 0.435600
# Epoch 13, CIFAR-10 Batch 4:  Loss:     1.5329
# Accuracy: 0.431200
# Epoch 13, CIFAR-10 Batch 5:  Loss:     1.6009
# Accuracy: 0.421200
# Epoch 14, CIFAR-10 Batch 1:  Loss:     1.6821
# Accuracy: 0.405400
# Epoch 14, CIFAR-10 Batch 2:  Loss:     1.6270
# Accuracy: 0.410600
# Epoch 14, CIFAR-10 Batch 3:  Loss:     1.5473
# Accuracy: 0.425600
# Epoch 14, CIFAR-10 Batch 4:  Loss:     1.5389
# Accuracy: 0.426400
# Epoch 14, CIFAR-10 Batch 5:  Loss:     1.6150
# Accuracy: 0.414800
# Epoch 15, CIFAR-10 Batch 1:  Loss:     1.6582
# Accuracy: 0.406600
# Epoch 15, CIFAR-10 Batch 2:  Loss:     1.6230
# Accuracy: 0.435400
# Epoch 15, CIFAR-10 Batch 3:  Loss:     1.5270
# Accuracy: 0.421200
# Epoch 15, CIFAR-10 Batch 4:  Loss:     1.5215
# Accuracy: 0.436200
# Epoch 15, CIFAR-10 Batch 5:  Loss:     1.5840
# Accuracy: 0.421400
# Epoch 16, CIFAR-10 Batch 1:  Loss:     1.6347
# Accuracy: 0.433800
# Epoch 16, CIFAR-10 Batch 2:  Loss:     1.5999
# Accuracy: 0.435800
# Epoch 16, CIFAR-10 Batch 3:  Loss:     1.5136
# Accuracy: 0.433600
# Epoch 16, CIFAR-10 Batch 4:  Loss:     1.4941
# Accuracy: 0.427800
# Epoch 16, CIFAR-10 Batch 5:  Loss:     1.5730
# Accuracy: 0.429200
# Epoch 17, CIFAR-10 Batch 1:  Loss:     1.6392
# Accuracy: 0.445600
# Epoch 17, CIFAR-10 Batch 2:  Loss:     1.5747
# Accuracy: 0.438400
# Epoch 17, CIFAR-10 Batch 3:  Loss:     1.5007
# Accuracy: 0.453400
# Epoch 17, CIFAR-10 Batch 4:  Loss:     1.5028
# Accuracy: 0.418800
# Epoch 17, CIFAR-10 Batch 5:  Loss:     1.5655
# Accuracy: 0.447400
# Epoch 18, CIFAR-10 Batch 1:  Loss:     1.6276
# Accuracy: 0.444000
# Epoch 18, CIFAR-10 Batch 2:  Loss:     1.5554
# Accuracy: 0.441000
# Epoch 18, CIFAR-10 Batch 3:  Loss:     1.4894
# Accuracy: 0.454000
# Epoch 18, CIFAR-10 Batch 4:  Loss:     1.4843
# Accuracy: 0.448400
# Epoch 18, CIFAR-10 Batch 5:  Loss:     1.5446
# Accuracy: 0.446200
# Epoch 19, CIFAR-10 Batch 1:  Loss:     1.6131
# Accuracy: 0.444400
# Epoch 19, CIFAR-10 Batch 2:  Loss:     1.5513
# Accuracy: 0.450000
# Epoch 19, CIFAR-10 Batch 3:  Loss:     1.4952
# Accuracy: 0.450000
# Epoch 19, CIFAR-10 Batch 4:  Loss:     1.4492
# Accuracy: 0.452600
# Epoch 19, CIFAR-10 Batch 5:  Loss:     1.5296
# Accuracy: 0.458200
# Epoch 20, CIFAR-10 Batch 1:  Loss:     1.6398
# Accuracy: 0.443400
# Epoch 20, CIFAR-10 Batch 2:  Loss:     1.5328
# Accuracy: 0.443800
# Epoch 20, CIFAR-10 Batch 3:  Loss:     1.4786
# Accuracy: 0.450400
# Epoch 20, CIFAR-10 Batch 4:  Loss:     1.4465
# Accuracy: 0.448600
# Epoch 20, CIFAR-10 Batch 5:  Loss:     1.5319
# Accuracy: 0.464200
# Epoch 21, CIFAR-10 Batch 1:  Loss:     1.6192
# Accuracy: 0.436400
# Epoch 21, CIFAR-10 Batch 2:  Loss:     1.5476
# Accuracy: 0.412400
# Epoch 21, CIFAR-10 Batch 3:  Loss:     1.4652
# Accuracy: 0.444000
# Epoch 21, CIFAR-10 Batch 4:  Loss:     1.4480
# Accuracy: 0.455800
# Epoch 21, CIFAR-10 Batch 5:  Loss:     1.5028
# Accuracy: 0.443800
# Epoch 22, CIFAR-10 Batch 1:  Loss:     1.5599
# Accuracy: 0.453600
# Epoch 22, CIFAR-10 Batch 2:  Loss:     1.5316
# Accuracy: 0.447400
# Epoch 22, CIFAR-10 Batch 3:  Loss:     1.4709
# Accuracy: 0.440800
# Epoch 22, CIFAR-10 Batch 4:  Loss:     1.4433
# Accuracy: 0.460200
# Epoch 22, CIFAR-10 Batch 5:  Loss:     1.5003
# Accuracy: 0.452200
# Epoch 23, CIFAR-10 Batch 1:  Loss:     1.6012
# Accuracy: 0.446000
# Epoch 23, CIFAR-10 Batch 2:  Loss:     1.5058
# Accuracy: 0.464400
# Epoch 23, CIFAR-10 Batch 3:  Loss:     1.4314
# Accuracy: 0.462000
# Epoch 23, CIFAR-10 Batch 4:  Loss:     1.4477
# Accuracy: 0.452200
# Epoch 23, CIFAR-10 Batch 5:  Loss:     1.5022
# Accuracy: 0.446800
# Epoch 24, CIFAR-10 Batch 1:  Loss:     1.5646
# Accuracy: 0.450200
# Epoch 24, CIFAR-10 Batch 2:  Loss:     1.5013
# Accuracy: 0.446400
# Epoch 24, CIFAR-10 Batch 3:  Loss:     1.4560
# Accuracy: 0.462600
# Epoch 24, CIFAR-10 Batch 4:  Loss:     1.4562
# Accuracy: 0.448600
# Epoch 24, CIFAR-10 Batch 5:  Loss:     1.4967
# Accuracy: 0.424600
# Epoch 25, CIFAR-10 Batch 1:  Loss:     1.6082
# Accuracy: 0.441000
# Epoch 25, CIFAR-10 Batch 2:  Loss:     1.5184
# Accuracy: 0.453200
# Epoch 25, CIFAR-10 Batch 3:  Loss:     1.4357
# Accuracy: 0.442400
# Epoch 25, CIFAR-10 Batch 4:  Loss:     1.4373
# Accuracy: 0.462000
# Epoch 25, CIFAR-10 Batch 5:  Loss:     1.4935
# Accuracy: 0.465800
# Epoch 26, CIFAR-10 Batch 1:  Loss:     1.5769
# Accuracy: 0.450600
# Epoch 26, CIFAR-10 Batch 2:  Loss:     1.4969
# Accuracy: 0.459600
# Epoch 26, CIFAR-10 Batch 3:  Loss:     1.4392
# Accuracy: 0.459600
# Epoch 26, CIFAR-10 Batch 4:  Loss:     1.4184
# Accuracy: 0.459600
# Epoch 26, CIFAR-10 Batch 5:  Loss:     1.5018
# Accuracy: 0.457400
# Epoch 27, CIFAR-10 Batch 1:  Loss:     1.5557
# Accuracy: 0.454000
# Epoch 27, CIFAR-10 Batch 2:  Loss:     1.5100
# Accuracy: 0.461800
# Epoch 27, CIFAR-10 Batch 3:  Loss:     1.4028
# Accuracy: 0.470800
# Epoch 27, CIFAR-10 Batch 4:  Loss:     1.4114
# Accuracy: 0.482200
# Epoch 27, CIFAR-10 Batch 5:  Loss:     1.4870
# Accuracy: 0.458600
# Epoch 28, CIFAR-10 Batch 1:  Loss:     1.5466
# Accuracy: 0.458200
# Epoch 28, CIFAR-10 Batch 2:  Loss:     1.5240
# Accuracy: 0.458400
# Epoch 28, CIFAR-10 Batch 3:  Loss:     1.4100
# Accuracy: 0.461000
# Epoch 28, CIFAR-10 Batch 4:  Loss:     1.4326
# Accuracy: 0.455600
# Epoch 28, CIFAR-10 Batch 5:  Loss:     1.4781
# Accuracy: 0.452600
# Epoch 29, CIFAR-10 Batch 1:  Loss:     1.5647
# Accuracy: 0.453800
# Epoch 29, CIFAR-10 Batch 2:  Loss:     1.4890
# Accuracy: 0.468600
# Epoch 29, CIFAR-10 Batch 3:  Loss:     1.4062
# Accuracy: 0.460400
# Epoch 29, CIFAR-10 Batch 4:  Loss:     1.3992
# Accuracy: 0.464600
# Epoch 29, CIFAR-10 Batch 5:  Loss:     1.4711
# Accuracy: 0.452800
# Epoch 30, CIFAR-10 Batch 1:  Loss:     1.5309
# Accuracy: 0.467200
# Epoch 30, CIFAR-10 Batch 2:  Loss:     1.4746
# Accuracy: 0.461800
# Epoch 30, CIFAR-10 Batch 3:  Loss:     1.4191
# Accuracy: 0.451800
# Epoch 30, CIFAR-10 Batch 4:  Loss:     1.4016
# Accuracy: 0.460800
# Epoch 30, CIFAR-10 Batch 5:  Loss:     1.4724
# Accuracy: 0.476200
# Epoch 31, CIFAR-10 Batch 1:  Loss:     1.5768
# Accuracy: 0.452000
# Epoch 31, CIFAR-10 Batch 2:  Loss:     1.5052
# Accuracy: 0.465400
# Epoch 31, CIFAR-10 Batch 3:  Loss:     1.3988
# Accuracy: 0.463200
# Epoch 31, CIFAR-10 Batch 4:  Loss:     1.3990
# Accuracy: 0.460000
# Epoch 31, CIFAR-10 Batch 5:  Loss:     1.4507
# Accuracy: 0.463800
# Epoch 32, CIFAR-10 Batch 1:  Loss:     1.5309
# Accuracy: 0.473800
# Epoch 32, CIFAR-10 Batch 2:  Loss:     1.4991
# Accuracy: 0.479000
# Epoch 32, CIFAR-10 Batch 3:  Loss:     1.4250
# Accuracy: 0.453200
# Epoch 32, CIFAR-10 Batch 4:  Loss:     1.4226
# Accuracy: 0.449800
# Epoch 32, CIFAR-10 Batch 5:  Loss:     1.4786
# Accuracy: 0.461200
# Epoch 33, CIFAR-10 Batch 1:  Loss:     1.5727
# Accuracy: 0.463800
# Epoch 33, CIFAR-10 Batch 2:  Loss:     1.4819
# Accuracy: 0.472800
# Epoch 33, CIFAR-10 Batch 3:  Loss:     1.3880
# Accuracy: 0.474000
# Epoch 33, CIFAR-10 Batch 4:  Loss:     1.3974
# Accuracy: 0.472400
# Epoch 33, CIFAR-10 Batch 5:  Loss:     1.4467
# Accuracy: 0.463600
# Epoch 34, CIFAR-10 Batch 1:  Loss:     1.5474
# Accuracy: 0.455800
# Epoch 34, CIFAR-10 Batch 2:  Loss:     1.4907
# Accuracy: 0.468600
# Epoch 34, CIFAR-10 Batch 3:  Loss:     1.3948
# Accuracy: 0.470200
# Epoch 34, CIFAR-10 Batch 4:  Loss:     1.4023
# Accuracy: 0.466000
# Epoch 34, CIFAR-10 Batch 5:  Loss:     1.4637
# Accuracy: 0.472200
# Epoch 35, CIFAR-10 Batch 1:  Loss:     1.5473
# Accuracy: 0.458600
# Epoch 35, CIFAR-10 Batch 2:  Loss:     1.4706
# Accuracy: 0.474600
# Epoch 35, CIFAR-10 Batch 3:  Loss:     1.3828
# Accuracy: 0.471200
# Epoch 35, CIFAR-10 Batch 4:  Loss:     1.3877
# Accuracy: 0.475200
# Epoch 35, CIFAR-10 Batch 5:  Loss:     1.4357
# Accuracy: 0.462400
# Epoch 36, CIFAR-10 Batch 1:  Loss:     1.5285
# Accuracy: 0.471000
# Epoch 36, CIFAR-10 Batch 2:  Loss:     1.4647
# Accuracy: 0.462400
# Epoch 36, CIFAR-10 Batch 3:  Loss:     1.3954
# Accuracy: 0.478000
# Epoch 36, CIFAR-10 Batch 4:  Loss:     1.3925
# Accuracy: 0.467000
# Epoch 36, CIFAR-10 Batch 5:  Loss:     1.4691
# Accuracy: 0.462600
# Epoch 37, CIFAR-10 Batch 1:  Loss:     1.5446
# Accuracy: 0.473200
# Epoch 37, CIFAR-10 Batch 2:  Loss:     1.4428
# Accuracy: 0.458600
# Epoch 37, CIFAR-10 Batch 3:  Loss:     1.3873
# Accuracy: 0.478600
# Epoch 37, CIFAR-10 Batch 4:  Loss:     1.4070
# Accuracy: 0.464200
# Epoch 37, CIFAR-10 Batch 5:  Loss:     1.4443
# Accuracy: 0.473800
# Epoch 38, CIFAR-10 Batch 1:  Loss:     1.5259
# Accuracy: 0.465600
# Epoch 38, CIFAR-10 Batch 2:  Loss:     1.4812
# Accuracy: 0.460600
# Epoch 38, CIFAR-10 Batch 3:  Loss:     1.3762
# Accuracy: 0.480200
# Epoch 38, CIFAR-10 Batch 4:  Loss:     1.4074
# Accuracy: 0.463400
# Epoch 38, CIFAR-10 Batch 5:  Loss:     1.4327
# Accuracy: 0.483800
# Epoch 39, CIFAR-10 Batch 1:  Loss:     1.5157
# Accuracy: 0.478800
# Epoch 39, CIFAR-10 Batch 2:  Loss:     1.4587
# Accuracy: 0.460800
# Epoch 39, CIFAR-10 Batch 3:  Loss:     1.3684
# Accuracy: 0.477000
# Epoch 39, CIFAR-10 Batch 4:  Loss:     1.4005
# Accuracy: 0.469000
# Epoch 39, CIFAR-10 Batch 5:  Loss:     1.4430
# Accuracy: 0.475200
# Epoch 40, CIFAR-10 Batch 1:  Loss:     1.5023
# Accuracy: 0.471000
# Epoch 40, CIFAR-10 Batch 2:  Loss:     1.4478
# Accuracy: 0.469800
# Epoch 40, CIFAR-10 Batch 3:  Loss:     1.3846
# Accuracy: 0.458800
# Epoch 40, CIFAR-10 Batch 4:  Loss:     1.4142
# Accuracy: 0.460400
# Epoch 40, CIFAR-10 Batch 5:  Loss:     1.4203
# Accuracy: 0.494000
# Epoch 41, CIFAR-10 Batch 1:  Loss:     1.5089
# Accuracy: 0.463800
# Epoch 41, CIFAR-10 Batch 2:  Loss:     1.4770
# Accuracy: 0.473000
# Epoch 41, CIFAR-10 Batch 3:  Loss:     1.3806
# Accuracy: 0.472400
# Epoch 41, CIFAR-10 Batch 4:  Loss:     1.3899
# Accuracy: 0.463200
# Epoch 41, CIFAR-10 Batch 5:  Loss:     1.4264
# Accuracy: 0.470000
# Epoch 42, CIFAR-10 Batch 1:  Loss:     1.4970
# Accuracy: 0.473000
# Epoch 42, CIFAR-10 Batch 2:  Loss:     1.4448
# Accuracy: 0.460600
# Epoch 42, CIFAR-10 Batch 3:  Loss:     1.3887
# Accuracy: 0.453000
# Epoch 42, CIFAR-10 Batch 4:  Loss:     1.3794
# Accuracy: 0.465800
# Epoch 42, CIFAR-10 Batch 5:  Loss:     1.4411
# Accuracy: 0.491600
# Epoch 43, CIFAR-10 Batch 1:  Loss:     1.5128
# Accuracy: 0.468200
# Epoch 43, CIFAR-10 Batch 2:  Loss:     1.4282
# Accuracy: 0.491000
# Epoch 43, CIFAR-10 Batch 3:  Loss:     1.3714
# Accuracy: 0.462000
# Epoch 43, CIFAR-10 Batch 4:  Loss:     1.3724
# Accuracy: 0.477400
# Epoch 43, CIFAR-10 Batch 5:  Loss:     1.4250
# Accuracy: 0.464800
# Epoch 44, CIFAR-10 Batch 1:  Loss:     1.5064
# Accuracy: 0.476400
# Epoch 44, CIFAR-10 Batch 2:  Loss:     1.4342
# Accuracy: 0.486000
# Epoch 44, CIFAR-10 Batch 3:  Loss:     1.3434
# Accuracy: 0.475800
# Epoch 44, CIFAR-10 Batch 4:  Loss:     1.3666
# Accuracy: 0.476200
# Epoch 44, CIFAR-10 Batch 5:  Loss:     1.4042
# Accuracy: 0.468400
# Epoch 45, CIFAR-10 Batch 1:  Loss:     1.5113
# Accuracy: 0.480600
# Epoch 45, CIFAR-10 Batch 2:  Loss:     1.4408
# Accuracy: 0.463400
# Epoch 45, CIFAR-10 Batch 3:  Loss:     1.3930
# Accuracy: 0.475000
# Epoch 45, CIFAR-10 Batch 4:  Loss:     1.3970
# Accuracy: 0.479000
# Epoch 45, CIFAR-10 Batch 5:  Loss:     1.4229
# Accuracy: 0.474600
# Epoch 46, CIFAR-10 Batch 1:  Loss:     1.5046
# Accuracy: 0.475000
# Epoch 46, CIFAR-10 Batch 2:  Loss:     1.4444
# Accuracy: 0.474000
# Epoch 46, CIFAR-10 Batch 3:  Loss:     1.3602
# Accuracy: 0.474400
# Epoch 46, CIFAR-10 Batch 4:  Loss:     1.3648
# Accuracy: 0.478600
# Epoch 46, CIFAR-10 Batch 5:  Loss:     1.4129
# Accuracy: 0.484400
# Epoch 47, CIFAR-10 Batch 1:  Loss:     1.4841
# Accuracy: 0.478400
# Epoch 47, CIFAR-10 Batch 2:  Loss:     1.4628
# Accuracy: 0.478400
# Epoch 47, CIFAR-10 Batch 3:  Loss:     1.3871
# Accuracy: 0.461000
# Epoch 47, CIFAR-10 Batch 4:  Loss:     1.3620
# Accuracy: 0.477200
# Epoch 47, CIFAR-10 Batch 5:  Loss:     1.4105
# Accuracy: 0.483200
# Epoch 48, CIFAR-10 Batch 1:  Loss:     1.4974
# Accuracy: 0.483800
# Epoch 48, CIFAR-10 Batch 2:  Loss:     1.4256
# Accuracy: 0.477400
# Epoch 48, CIFAR-10 Batch 3:  Loss:     1.3414
# Accuracy: 0.480000
# Epoch 48, CIFAR-10 Batch 4:  Loss:     1.3811
# Accuracy: 0.480600
# Epoch 48, CIFAR-10 Batch 5:  Loss:     1.4234
# Accuracy: 0.471400
# Epoch 49, CIFAR-10 Batch 1:  Loss:     1.4791
# Accuracy: 0.482400
# Epoch 49, CIFAR-10 Batch 2:  Loss:     1.4297
# Accuracy: 0.485200
# Epoch 49, CIFAR-10 Batch 3:  Loss:     1.3657
# Accuracy: 0.458200
# Epoch 49, CIFAR-10 Batch 4:  Loss:     1.3737
# Accuracy: 0.477000
# Epoch 49, CIFAR-10 Batch 5:  Loss:     1.4146
# Accuracy: 0.478400
# Epoch 50, CIFAR-10 Batch 1:  Loss:     1.4935
# Accuracy: 0.477600
# Epoch 50, CIFAR-10 Batch 2:  Loss:     1.4159
# Accuracy: 0.473800
# Epoch 50, CIFAR-10 Batch 3:  Loss:     1.3855
# Accuracy: 0.468600
# Epoch 50, CIFAR-10 Batch 4:  Loss:     1.3877
# Accuracy: 0.480000
# Epoch 50, CIFAR-10 Batch 5:  Loss:     1.4158
# Accuracy: 0.475200
# Epoch 51, CIFAR-10 Batch 1:  Loss:     1.4951
# Accuracy: 0.481000
# Epoch 51, CIFAR-10 Batch 2:  Loss:     1.4485
# Accuracy: 0.454400
# Epoch 51, CIFAR-10 Batch 3:  Loss:     1.3451
# Accuracy: 0.486000
# Epoch 51, CIFAR-10 Batch 4:  Loss:     1.3753
# Accuracy: 0.476600
# Epoch 51, CIFAR-10 Batch 5:  Loss:     1.3907
# Accuracy: 0.489600
# Epoch 52, CIFAR-10 Batch 1:  Loss:     1.4969
# Accuracy: 0.482600
# Epoch 52, CIFAR-10 Batch 2:  Loss:     1.4311
# Accuracy: 0.481400
# Epoch 52, CIFAR-10 Batch 3:  Loss:     1.3487
# Accuracy: 0.489600
# Epoch 52, CIFAR-10 Batch 4:  Loss:     1.3750
# Accuracy: 0.473400
# Epoch 52, CIFAR-10 Batch 5:  Loss:     1.4057
# Accuracy: 0.474400
# Epoch 53, CIFAR-10 Batch 1:  Loss:     1.5109
# Accuracy: 0.471400
# Epoch 53, CIFAR-10 Batch 2:  Loss:     1.4220
# Accuracy: 0.483200
# Epoch 53, CIFAR-10 Batch 3:  Loss:     1.3555
# Accuracy: 0.468000
# Epoch 53, CIFAR-10 Batch 4:  Loss:     1.3724
# Accuracy: 0.476400
# Epoch 53, CIFAR-10 Batch 5:  Loss:     1.3988
# Accuracy: 0.477000
# Epoch 54, CIFAR-10 Batch 1:  Loss:     1.4768
# Accuracy: 0.474000
# Epoch 54, CIFAR-10 Batch 2:  Loss:     1.4319
# Accuracy: 0.464800
# Epoch 54, CIFAR-10 Batch 3:  Loss:     1.3477
# Accuracy: 0.471000
# Epoch 54, CIFAR-10 Batch 4:  Loss:     1.3729
# Accuracy: 0.477600
# Epoch 54, CIFAR-10 Batch 5:  Loss:     1.4183
# Accuracy: 0.475800
# Epoch 55, CIFAR-10 Batch 1:  Loss:     1.4663
# Accuracy: 0.477800
# Epoch 55, CIFAR-10 Batch 2:  Loss:     1.4426
# Accuracy: 0.474800
# Epoch 55, CIFAR-10 Batch 3:  Loss:     1.3640
# Accuracy: 0.480600
# Epoch 55, CIFAR-10 Batch 4:  Loss:     1.3489
# Accuracy: 0.477000
# Epoch 55, CIFAR-10 Batch 5:  Loss:     1.3881
# Accuracy: 0.483400
# Epoch 56, CIFAR-10 Batch 1:  Loss:     1.5033
# Accuracy: 0.475200
# Epoch 56, CIFAR-10 Batch 2:  Loss:     1.4198
# Accuracy: 0.484000
# Epoch 56, CIFAR-10 Batch 3:  Loss:     1.3554
# Accuracy: 0.466800
# Epoch 56, CIFAR-10 Batch 4:  Loss:     1.3628
# Accuracy: 0.491200
# Epoch 56, CIFAR-10 Batch 5:  Loss:     1.3773
# Accuracy: 0.483400
# Epoch 57, CIFAR-10 Batch 1:  Loss:     1.5200
# Accuracy: 0.470400
# Epoch 57, CIFAR-10 Batch 2:  Loss:     1.4050
# Accuracy: 0.486800
# Epoch 57, CIFAR-10 Batch 3:  Loss:     1.3452
# Accuracy: 0.475200
# Epoch 57, CIFAR-10 Batch 4:  Loss:     1.3509
# Accuracy: 0.479000
# Epoch 57, CIFAR-10 Batch 5:  Loss:     1.4097
# Accuracy: 0.489600
# Epoch 58, CIFAR-10 Batch 1:  Loss:     1.4922
# Accuracy: 0.471200
# Epoch 58, CIFAR-10 Batch 2:  Loss:     1.4233
# Accuracy: 0.492600
# Epoch 58, CIFAR-10 Batch 3:  Loss:     1.3142
# Accuracy: 0.472800
# Epoch 58, CIFAR-10 Batch 4:  Loss:     1.3566
# Accuracy: 0.477600
# Epoch 58, CIFAR-10 Batch 5:  Loss:     1.3913
# Accuracy: 0.472000
# Epoch 59, CIFAR-10 Batch 1:  Loss:     1.4994
# Accuracy: 0.472600
# Epoch 59, CIFAR-10 Batch 2:  Loss:     1.4236
# Accuracy: 0.471200
# Epoch 59, CIFAR-10 Batch 3:  Loss:     1.3652
# Accuracy: 0.469400
# Epoch 59, CIFAR-10 Batch 4:  Loss:     1.3832
# Accuracy: 0.469200
# Epoch 59, CIFAR-10 Batch 5:  Loss:     1.3883
# Accuracy: 0.475400
# Epoch 60, CIFAR-10 Batch 1:  Loss:     1.4619
# Accuracy: 0.477000
# Epoch 60, CIFAR-10 Batch 2:  Loss:     1.4070
# Accuracy: 0.477200
# Epoch 60, CIFAR-10 Batch 3:  Loss:     1.3525
# Accuracy: 0.467800
# Epoch 60, CIFAR-10 Batch 4:  Loss:     1.3503
# Accuracy: 0.488600
# Epoch 60, CIFAR-10 Batch 5:  Loss:     1.3914
# Accuracy: 0.476800
# Epoch 61, CIFAR-10 Batch 1:  Loss:     1.4727
# Accuracy: 0.477600
# Epoch 61, CIFAR-10 Batch 2:  Loss:     1.4147
# Accuracy: 0.483600
# Epoch 61, CIFAR-10 Batch 3:  Loss:     1.3866
# Accuracy: 0.471600
# Epoch 61, CIFAR-10 Batch 4:  Loss:     1.3839
# Accuracy: 0.471400
# Epoch 61, CIFAR-10 Batch 5:  Loss:     1.4064
# Accuracy: 0.478200
# Epoch 62, CIFAR-10 Batch 1:  Loss:     1.4723
# Accuracy: 0.478000
# Epoch 62, CIFAR-10 Batch 2:  Loss:     1.4269
# Accuracy: 0.478600
# Epoch 62, CIFAR-10 Batch 3:  Loss:     1.3244
# Accuracy: 0.489200
# Epoch 62, CIFAR-10 Batch 4:  Loss:     1.3894
# Accuracy: 0.475200
# Epoch 62, CIFAR-10 Batch 5:  Loss:     1.4102
# Accuracy: 0.474200
# Epoch 63, CIFAR-10 Batch 1:  Loss:     1.4813
# Accuracy: 0.477800
# Epoch 63, CIFAR-10 Batch 2:  Loss:     1.4001
# Accuracy: 0.493200
# Epoch 63, CIFAR-10 Batch 3:  Loss:     1.3491
# Accuracy: 0.485400
# Epoch 63, CIFAR-10 Batch 4:  Loss:     1.3805
# Accuracy: 0.476200
# Epoch 63, CIFAR-10 Batch 5:  Loss:     1.3775
# Accuracy: 0.478800
# Epoch 64, CIFAR-10 Batch 1:  Loss:     1.4987
# Accuracy: 0.481800
# Epoch 64, CIFAR-10 Batch 2:  Loss:     1.4185
# Accuracy: 0.478400
# Epoch 64, CIFAR-10 Batch 3:  Loss:     1.3366
# Accuracy: 0.470000
# Epoch 64, CIFAR-10 Batch 4:  Loss:     1.3575
# Accuracy: 0.482000
# Epoch 64, CIFAR-10 Batch 5:  Loss:     1.3870
# Accuracy: 0.468800
# Epoch 65, CIFAR-10 Batch 1:  Loss:     1.4927
# Accuracy: 0.484200
# Epoch 65, CIFAR-10 Batch 2:  Loss:     1.3952
# Accuracy: 0.478800
# Epoch 65, CIFAR-10 Batch 3:  Loss:     1.3585
# Accuracy: 0.469800
# Epoch 65, CIFAR-10 Batch 4:  Loss:     1.3645
# Accuracy: 0.482600
# Epoch 65, CIFAR-10 Batch 5:  Loss:     1.3883
# Accuracy: 0.469200
# Epoch 66, CIFAR-10 Batch 1:  Loss:     1.5079
# Accuracy: 0.479000
# Epoch 66, CIFAR-10 Batch 2:  Loss:     1.4136
# Accuracy: 0.463200
# Epoch 66, CIFAR-10 Batch 3:  Loss:     1.3534
# Accuracy: 0.466600
# Epoch 66, CIFAR-10 Batch 4:  Loss:     1.3693
# Accuracy: 0.469600
# Epoch 66, CIFAR-10 Batch 5:  Loss:     1.3839
# Accuracy: 0.481200
# Epoch 67, CIFAR-10 Batch 1:  Loss:     1.5049
# Accuracy: 0.472800
# Epoch 67, CIFAR-10 Batch 2:  Loss:     1.3838
# Accuracy: 0.481800
# Epoch 67, CIFAR-10 Batch 3:  Loss:     1.3587
# Accuracy: 0.474200
# Epoch 67, CIFAR-10 Batch 4:  Loss:     1.3499
# Accuracy: 0.479800
# Epoch 67, CIFAR-10 Batch 5:  Loss:     1.3740
# Accuracy: 0.475600
# Epoch 68, CIFAR-10 Batch 1:  Loss:     1.4900
# Accuracy: 0.472600
# Epoch 68, CIFAR-10 Batch 2:  Loss:     1.3954
# Accuracy: 0.492400
# Epoch 68, CIFAR-10 Batch 3:  Loss:     1.3245
# Accuracy: 0.484400
# Epoch 68, CIFAR-10 Batch 4:  Loss:     1.3436
# Accuracy: 0.484800
# Epoch 68, CIFAR-10 Batch 5:  Loss:     1.3857
# Accuracy: 0.483200
# Epoch 69, CIFAR-10 Batch 1:  Loss:     1.4702
# Accuracy: 0.470600
# Epoch 69, CIFAR-10 Batch 2:  Loss:     1.4278
# Accuracy: 0.480400
# Epoch 69, CIFAR-10 Batch 3:  Loss:     1.3425
# Accuracy: 0.483800
# Epoch 69, CIFAR-10 Batch 4:  Loss:     1.3332
# Accuracy: 0.486600
# Epoch 69, CIFAR-10 Batch 5:  Loss:     1.3829
# Accuracy: 0.497400
# Epoch 70, CIFAR-10 Batch 1:  Loss:     1.4693
# Accuracy: 0.487600
# Epoch 70, CIFAR-10 Batch 2:  Loss:     1.3954
# Accuracy: 0.479800
# Epoch 70, CIFAR-10 Batch 3:  Loss:     1.3466
# Accuracy: 0.479000
# Epoch 70, CIFAR-10 Batch 4:  Loss:     1.3458
# Accuracy: 0.480800
# Epoch 70, CIFAR-10 Batch 5:  Loss:     1.3943
# Accuracy: 0.477200
# Epoch 71, CIFAR-10 Batch 1:  Loss:     1.4801
# Accuracy: 0.484400
# Epoch 71, CIFAR-10 Batch 2:  Loss:     1.4040
# Accuracy: 0.488800
# Epoch 71, CIFAR-10 Batch 3:  Loss:     1.3545
# Accuracy: 0.473400
# Epoch 71, CIFAR-10 Batch 4:  Loss:     1.3543
# Accuracy: 0.481600
# Epoch 71, CIFAR-10 Batch 5:  Loss:     1.3618
# Accuracy: 0.477000
# Epoch 72, CIFAR-10 Batch 1:  Loss:     1.4809
# Accuracy: 0.486800
# Epoch 72, CIFAR-10 Batch 2:  Loss:     1.4022
# Accuracy: 0.483000
# Epoch 72, CIFAR-10 Batch 3:  Loss:     1.3466
# Accuracy: 0.493000
# Epoch 72, CIFAR-10 Batch 4:  Loss:     1.3576
# Accuracy: 0.485600
# Epoch 72, CIFAR-10 Batch 5:  Loss:     1.3800
# Accuracy: 0.480400
# Epoch 73, CIFAR-10 Batch 1:  Loss:     1.4845
# Accuracy: 0.486400
# Epoch 73, CIFAR-10 Batch 2:  Loss:     1.3886
# Accuracy: 0.482400
# Epoch 73, CIFAR-10 Batch 3:  Loss:     1.3519
# Accuracy: 0.481400
# Epoch 73, CIFAR-10 Batch 4:  Loss:     1.3671
# Accuracy: 0.484200
# Epoch 73, CIFAR-10 Batch 5:  Loss:     1.3514
# Accuracy: 0.483200
# Epoch 74, CIFAR-10 Batch 1:  Loss:     1.4747
# Accuracy: 0.488800
# Epoch 74, CIFAR-10 Batch 2:  Loss:     1.4015
# Accuracy: 0.492200
# Epoch 74, CIFAR-10 Batch 3:  Loss:     1.3433
# Accuracy: 0.484000
# Epoch 74, CIFAR-10 Batch 4:  Loss:     1.3591
# Accuracy: 0.472000
# Epoch 74, CIFAR-10 Batch 5:  Loss:     1.4004
# Accuracy: 0.483000
# Epoch 75, CIFAR-10 Batch 1:  Loss:     1.4685
# Accuracy: 0.490800
# Epoch 75, CIFAR-10 Batch 2:  Loss:     1.4006
# Accuracy: 0.473200
# Epoch 75, CIFAR-10 Batch 3:  Loss:     1.3422
# Accuracy: 0.464800
# Epoch 75, CIFAR-10 Batch 4:  Loss:     1.3765
# Accuracy: 0.462600
# Epoch 75, CIFAR-10 Batch 5:  Loss:     1.3637
# Accuracy: 0.498200
# Epoch 76, CIFAR-10 Batch 1:  Loss:     1.4702
# Accuracy: 0.492200
# Epoch 76, CIFAR-10 Batch 2:  Loss:     1.4058
# Accuracy: 0.495600
# Epoch 76, CIFAR-10 Batch 3:  Loss:     1.3310
# Accuracy: 0.495400
# Epoch 76, CIFAR-10 Batch 4:  Loss:     1.3719
# Accuracy: 0.474800
# Epoch 76, CIFAR-10 Batch 5:  Loss:     1.3668
# Accuracy: 0.482200
# Epoch 77, CIFAR-10 Batch 1:  Loss:     1.4919
# Accuracy: 0.491400
# Epoch 77, CIFAR-10 Batch 2:  Loss:     1.3913
# Accuracy: 0.477800
# Epoch 77, CIFAR-10 Batch 3:  Loss:     1.3581
# Accuracy: 0.494000
# Epoch 77, CIFAR-10 Batch 4:  Loss:     1.3363
# Accuracy: 0.494000
# Epoch 77, CIFAR-10 Batch 5:  Loss:     1.3906
# Accuracy: 0.476400
# Epoch 78, CIFAR-10 Batch 1:  Loss:     1.4876
# Accuracy: 0.480200
# Epoch 78, CIFAR-10 Batch 2:  Loss:     1.3857
# Accuracy: 0.489200
# Epoch 78, CIFAR-10 Batch 3:  Loss:     1.3067
# Accuracy: 0.483400
# Epoch 78, CIFAR-10 Batch 4:  Loss:     1.3636
# Accuracy: 0.475000
# Epoch 78, CIFAR-10 Batch 5:  Loss:     1.3668
# Accuracy: 0.486800
# Epoch 79, CIFAR-10 Batch 1:  Loss:     1.4755
# Accuracy: 0.486200
# Epoch 79, CIFAR-10 Batch 2:  Loss:     1.3950
# Accuracy: 0.479000
# Epoch 79, CIFAR-10 Batch 3:  Loss:     1.3342
# Accuracy: 0.475000
# Epoch 79, CIFAR-10 Batch 4:  Loss:     1.3266
# Accuracy: 0.482000
# Epoch 79, CIFAR-10 Batch 5:  Loss:     1.3589
# Accuracy: 0.483800
# Epoch 80, CIFAR-10 Batch 1:  Loss:     1.5045
# Accuracy: 0.475800
# Epoch 80, CIFAR-10 Batch 2:  Loss:     1.4149
# Accuracy: 0.483000
# Epoch 80, CIFAR-10 Batch 3:  Loss:     1.3199
# Accuracy: 0.497400
# Epoch 80, CIFAR-10 Batch 4:  Loss:     1.3277
# Accuracy: 0.477600
# Epoch 80, CIFAR-10 Batch 5:  Loss:     1.3780
# Accuracy: 0.479200
# Epoch 81, CIFAR-10 Batch 1:  Loss:     1.4952
# Accuracy: 0.487400
# Epoch 81, CIFAR-10 Batch 2:  Loss:     1.4249
# Accuracy: 0.487200
# Epoch 81, CIFAR-10 Batch 3:  Loss:     1.3343
# Accuracy: 0.475800
# Epoch 81, CIFAR-10 Batch 4:  Loss:     1.3375
# Accuracy: 0.494800
# Epoch 81, CIFAR-10 Batch 5:  Loss:     1.3726
# Accuracy: 0.486800
# Epoch 82, CIFAR-10 Batch 1:  Loss:     1.4919
# Accuracy: 0.486200
# Epoch 82, CIFAR-10 Batch 2:  Loss:     1.3963
# Accuracy: 0.487200
# Epoch 82, CIFAR-10 Batch 3:  Loss:     1.3360
# Accuracy: 0.474600
# Epoch 82, CIFAR-10 Batch 4:  Loss:     1.3285
# Accuracy: 0.492200
# Epoch 82, CIFAR-10 Batch 5:  Loss:     1.3710
# Accuracy: 0.476400
# Epoch 83, CIFAR-10 Batch 1:  Loss:     1.4825
# Accuracy: 0.480800
# Epoch 83, CIFAR-10 Batch 2:  Loss:     1.3878
# Accuracy: 0.491200
# Epoch 83, CIFAR-10 Batch 3:  Loss:     1.3130
# Accuracy: 0.496800
# Epoch 83, CIFAR-10 Batch 4:  Loss:     1.3441
# Accuracy: 0.477600
# Epoch 83, CIFAR-10 Batch 5:  Loss:     1.4101
# Accuracy: 0.477200
# Epoch 84, CIFAR-10 Batch 1:  Loss:     1.4804
# Accuracy: 0.482800
# Epoch 84, CIFAR-10 Batch 2:  Loss:     1.3678
# Accuracy: 0.477200
# Epoch 84, CIFAR-10 Batch 3:  Loss:     1.3185
# Accuracy: 0.487400
# Epoch 84, CIFAR-10 Batch 4:  Loss:     1.3548
# Accuracy: 0.478600
# Epoch 84, CIFAR-10 Batch 5:  Loss:     1.3816
# Accuracy: 0.475400
# Epoch 85, CIFAR-10 Batch 1:  Loss:     1.4769
# Accuracy: 0.475600
# Epoch 85, CIFAR-10 Batch 2:  Loss:     1.4095
# Accuracy: 0.478200
# Epoch 85, CIFAR-10 Batch 3:  Loss:     1.3330
# Accuracy: 0.491800
# Epoch 85, CIFAR-10 Batch 4:  Loss:     1.3474
# Accuracy: 0.483200
# Epoch 85, CIFAR-10 Batch 5:  Loss:     1.3722
# Accuracy: 0.484200
# Epoch 86, CIFAR-10 Batch 1:  Loss:     1.4712
# Accuracy: 0.488000
# Epoch 86, CIFAR-10 Batch 2:  Loss:     1.3845
# Accuracy: 0.469600
# Epoch 86, CIFAR-10 Batch 3:  Loss:     1.3283
# Accuracy: 0.496800
# Epoch 86, CIFAR-10 Batch 4:  Loss:     1.3458
# Accuracy: 0.486400
# Epoch 86, CIFAR-10 Batch 5:  Loss:     1.3562
# Accuracy: 0.500800
# Epoch 87, CIFAR-10 Batch 1:  Loss:     1.4606
# Accuracy: 0.489600
# Epoch 87, CIFAR-10 Batch 2:  Loss:     1.4025
# Accuracy: 0.473600
# Epoch 87, CIFAR-10 Batch 3:  Loss:     1.3158
# Accuracy: 0.480200
# Epoch 87, CIFAR-10 Batch 4:  Loss:     1.3610
# Accuracy: 0.491600
# Epoch 87, CIFAR-10 Batch 5:  Loss:     1.3664
# Accuracy: 0.475400
# Epoch 88, CIFAR-10 Batch 1:  Loss:     1.4533
# Accuracy: 0.486400
# Epoch 88, CIFAR-10 Batch 2:  Loss:     1.3929
# Accuracy: 0.487200
# Epoch 88, CIFAR-10 Batch 3:  Loss:     1.3137
# Accuracy: 0.487600
# Epoch 88, CIFAR-10 Batch 4:  Loss:     1.3435
# Accuracy: 0.482600
# Epoch 88, CIFAR-10 Batch 5:  Loss:     1.3568
# Accuracy: 0.491400
# Epoch 89, CIFAR-10 Batch 1:  Loss:     1.4488
# Accuracy: 0.489600
# Epoch 89, CIFAR-10 Batch 2:  Loss:     1.3913
# Accuracy: 0.479600
# Epoch 89, CIFAR-10 Batch 3:  Loss:     1.3395
# Accuracy: 0.483600
# Epoch 89, CIFAR-10 Batch 4:  Loss:     1.3319
# Accuracy: 0.493000
# Epoch 89, CIFAR-10 Batch 5:  Loss:     1.3669
# Accuracy: 0.493200
# Epoch 90, CIFAR-10 Batch 1:  Loss:     1.4434
# Accuracy: 0.480800
# Epoch 90, CIFAR-10 Batch 2:  Loss:     1.4019
# Accuracy: 0.484800
# Epoch 90, CIFAR-10 Batch 3:  Loss:     1.3272
# Accuracy: 0.474400
# Epoch 90, CIFAR-10 Batch 4:  Loss:     1.3206
# Accuracy: 0.495200
# Epoch 90, CIFAR-10 Batch 5:  Loss:     1.3508
# Accuracy: 0.482600
# Epoch 91, CIFAR-10 Batch 1:  Loss:     1.4856
# Accuracy: 0.477200
# Epoch 91, CIFAR-10 Batch 2:  Loss:     1.3938
# Accuracy: 0.481000
# Epoch 91, CIFAR-10 Batch 3:  Loss:     1.3190
# Accuracy: 0.493600
# Epoch 91, CIFAR-10 Batch 4:  Loss:     1.3520
# Accuracy: 0.479800
# Epoch 91, CIFAR-10 Batch 5:  Loss:     1.3410
# Accuracy: 0.482800
# Epoch 92, CIFAR-10 Batch 1:  Loss:     1.4668
# Accuracy: 0.489800
# Epoch 92, CIFAR-10 Batch 2:  Loss:     1.3792
# Accuracy: 0.502600
# Epoch 92, CIFAR-10 Batch 3:  Loss:     1.3258
# Accuracy: 0.482200
# Epoch 92, CIFAR-10 Batch 4:  Loss:     1.3284
# Accuracy: 0.490800
# Epoch 92, CIFAR-10 Batch 5:  Loss:     1.3439
# Accuracy: 0.493600
# Epoch 93, CIFAR-10 Batch 1:  Loss:     1.4537
# Accuracy: 0.483200
# Epoch 93, CIFAR-10 Batch 2:  Loss:     1.3763
# Accuracy: 0.484800
# Epoch 93, CIFAR-10 Batch 3:  Loss:     1.3364
# Accuracy: 0.483200
# Epoch 93, CIFAR-10 Batch 4:  Loss:     1.3218
# Accuracy: 0.506800
# Epoch 93, CIFAR-10 Batch 5:  Loss:     1.3552
# Accuracy: 0.493400
# Epoch 94, CIFAR-10 Batch 1:  Loss:     1.4519
# Accuracy: 0.483000
# Epoch 94, CIFAR-10 Batch 2:  Loss:     1.3819
# Accuracy: 0.478800
# Epoch 94, CIFAR-10 Batch 3:  Loss:     1.3429
# Accuracy: 0.482400
# Epoch 94, CIFAR-10 Batch 4:  Loss:     1.3346
# Accuracy: 0.503400
# Epoch 94, CIFAR-10 Batch 5:  Loss:     1.3640
# Accuracy: 0.485000
# Epoch 95, CIFAR-10 Batch 1:  Loss:     1.4589
# Accuracy: 0.481600
# Epoch 95, CIFAR-10 Batch 2:  Loss:     1.3818
# Accuracy: 0.493200
# Epoch 95, CIFAR-10 Batch 3:  Loss:     1.3218
# Accuracy: 0.496200
# Epoch 95, CIFAR-10 Batch 4:  Loss:     1.3306
# Accuracy: 0.485800
# Epoch 95, CIFAR-10 Batch 5:  Loss:     1.3444
# Accuracy: 0.479200
# Epoch 96, CIFAR-10 Batch 1:  Loss:     1.4518
# Accuracy: 0.485400
# Epoch 96, CIFAR-10 Batch 2:  Loss:     1.3859
# Accuracy: 0.484400
# Epoch 96, CIFAR-10 Batch 3:  Loss:     1.3329
# Accuracy: 0.473400
# Epoch 96, CIFAR-10 Batch 4:  Loss:     1.3121
# Accuracy: 0.481600
# Epoch 96, CIFAR-10 Batch 5:  Loss:     1.3834
# Accuracy: 0.507200
# Epoch 97, CIFAR-10 Batch 1:  Loss:     1.4459
# Accuracy: 0.491200
# Epoch 97, CIFAR-10 Batch 2:  Loss:     1.3923
# Accuracy: 0.491000
# Epoch 97, CIFAR-10 Batch 3:  Loss:     1.3213
# Accuracy: 0.496800
# Epoch 97, CIFAR-10 Batch 4:  Loss:     1.3170
# Accuracy: 0.488200
# Epoch 97, CIFAR-10 Batch 5:  Loss:     1.3707
# Accuracy: 0.479400
# Epoch 98, CIFAR-10 Batch 1:  Loss:     1.4355
# Accuracy: 0.493000
# Epoch 98, CIFAR-10 Batch 2:  Loss:     1.3954
# Accuracy: 0.470600
# Epoch 98, CIFAR-10 Batch 3:  Loss:     1.3171
# Accuracy: 0.489000
# Epoch 98, CIFAR-10 Batch 4:  Loss:     1.3198
# Accuracy: 0.503000
# Epoch 98, CIFAR-10 Batch 5:  Loss:     1.3712
# Accuracy: 0.484600
# Epoch 99, CIFAR-10 Batch 1:  Loss:     1.4437
# Accuracy: 0.495000
# Epoch 99, CIFAR-10 Batch 2:  Loss:     1.3812
# Accuracy: 0.493800
# Epoch 99, CIFAR-10 Batch 3:  Loss:     1.3097
# Accuracy: 0.483800
# Epoch 99, CIFAR-10 Batch 4:  Loss:     1.3358
# Accuracy: 0.485800
# Epoch 99, CIFAR-10 Batch 5:  Loss:     1.3649
# Accuracy: 0.473800
# Epoch 100, CIFAR-10 Batch 1:  Loss:     1.4401
# Accuracy: 0.495200
# Epoch 100, CIFAR-10 Batch 2:  Loss:     1.3729
# Accuracy: 0.512400
# Epoch 100, CIFAR-10 Batch 3:  Loss:     1.3076
# Accuracy: 0.508000
# Epoch 100, CIFAR-10 Batch 4:  Loss:     1.3490
# Accuracy: 0.483000
# Epoch 100, CIFAR-10 Batch 5:  Loss:     1.3415
# Accuracy: 0.487800

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.4908203139901161

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
